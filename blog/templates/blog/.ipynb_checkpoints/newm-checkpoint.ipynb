# %%
import re
import ast
import geoip2.webservice
import geoip2.database
import time

ll1='1234567890abcdefghijklmnopqrstuvwxyz'
listll1 = []
listnum1 = []
count = 0
listdataip = []
for inum in ll1[0:10]:
    listnum1.append(inum)
for ill in ll1:
    listll1.append(ill)
ll2 = 'd'
ll3 = 'pool'
ll4 = 'dsl'
ll5 = 'cpe'
ll6 = ['80-','206','68-']
ll7 = ['66-','80.']
ll8 = ['208']
ll9 = ['200']
ll10 = ['65-','64-']
ll11 =['216']
llerror = ['lj1036.inktomisearch.com','market-mail.panduit.com','lj1125.inktomisearch.com','mmscrm07-2.sac.overture.com',
           'proxy0.haifa.ac.il','mail.geovariances.fr','lj1162.inktomisearch.com','lj1052.inktomisearch.com','ts04-ip92.hevanet.com'
          ,'fw1.millardref.com','jacksonproject.cnc.bc.ca','fw.aub.dk','lordgun.org','lj1090.inktomisearch.com','bh02i525f01.au.ibm.com'
          ,'calcite.rhyolite.com','lj1088.inktomisearch.com','lj1089.inktomisearch.com','lj1016.inktomisearch.com','lj1025.inktomisearch.com'
          ,'prxint-sxb3.e-i.net','prxint-sxb2.e-i.net','rouble.cc.strath.ac.uk','lj1159.inktomisearch.com','p213.54.168.132.tisdip.tiscali.de'
          ,'lj1027.inktomisearch.com','mcl02.cnc.bc.ca','p5083cd5d.dip0.t-ipconnect.de','spot.nnacorp.com','spot.nnacorp.com'
          ,'lhr003a.dhl.com','lj1156.inktomisearch.com','lj1164.inktomisearch.com','lj1168.inktomisearch.com','acbf6930.ipt.aol.com'
          ,'barrie-ppp108371.sympatico.ca','lj1018.inktomisearch.com','px7wh.vc.shawcable.net','user-0c8hdkf.cable.mindspring.com'
          ,'lj1053.inktomisearch.com','pd95f99f2.dip.t-dialin.net','97082.upc.d','ns.wtbts.org','lj1223.inktomisearch.com','lj1024.inktomisearch.com'
          ,'vlp181.vlp.fi','lj1008.inktomisearch.com','lj','cr','pd','wc','ip','1-320.cnc.bc.ca','tr','ww','l07v-1-17.d1.club-internet.fr','fw','h194n2fls308o1033.telia.com'
           ,'ko','grandpa.mmlc.northwestern.edu','mt','ts','3_343_lt_someone','c-','wa','pp','pn','ia','og','ic','ca','yo','ad','pc','ns','d97082.upc-d.chello.nl'
          ,'2-110.cnc.bc.ca','ar','1-729.cnc.bc.ca','la','os','0x','1513.cps.virtua.com.br','sp','di','nb','2-238.cnc.bc.ca','ho','al','10.0.0.153','92-moc-6.acn.waw.pl']
adata = []
with open('C:/python3.7/Work_Sof2/Django/MyProject/blog/templates/blog/data.json',mode = 'r') as f:
    for line in f:
        r= ast.literal_eval(line)
        adata.append(r['IP'])
#print(adata)
for kk in adata:
        
    if kk in llerror or kk[0:2] in llerror:
        kk = '110.77.238.234'
        listdataip.append(kk)
    elif kk[0:3] in ll4 :
        ss1 = kk[4:16]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0] in listll1[13] :
        ss1 = kk[1:12]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0] in listll1[17] :
        ss1 = kk[1:12]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll6 :
        ss1 = kk[0:14]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll3 :
        ss1 = kk[5:18]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll7 :
        ss1 = kk[0:11]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll5 :
        ss1 = kk[4:18]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0] in listll1[10] :
        ss1 = kk[1:14]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll8 :
        ss1 = kk[0:13]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll9 :
        ss1 = kk[0:14]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll10 :
        ss1 = kk[0:12]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    elif kk[0:3] in ll11 :
        ss1 = kk[0:15]
        x = re.sub("\-", ".", ss1)
        listdataip.append(x)

    else:
        listdataip.append(kk)


# In[17]:



import geoip2.webservice
import geoip2.database
listcountry = []
listlat = []
listlon = []
reader = geoip2.database.Reader('GeoLite2-City.mmdb')
for ip1 in listdataip:
    response = reader.city(ip1)
    x1 = response.country.name
    x2 = response.location.latitude
    x3 = response.location.longitude
    listcountry.append(x1)
    listlat.append(x2)
    listlon.append(x3)


# In[27]:


import os
import re
import json
import geoip2.webservice
import geoip2.database
reader = geoip2.database.Reader('GeoLite2-City.mmdb')
response = reader.city('64.242.88.10')
response.location.longitude
response.location.latitude
i = 0
i2 = 0
regex = '([a-zA-Z0-9_.?+]+) - - \[(.*?)\] "(.*?)" (\d+) - "(.*?)" "(.*?)"'
regex2 = '([(\d\.)]+) - - \[(.*?)\] "(.*?)" (\d+\s\d+)'
regex3 = '([a-z0-9\-\_\.]*) - - \[(.*?)\] "(.*?)" (\d{3}) (\d*)'
l = []
IP = []
Date = []
Stat=[]
web = []
num = []
Country=[]
Lat=[]
Lon=[]
data = {}
location =  'D:/soft2/logfile/access_log'
for filename in os.listdir(location):
    if filename == 'access_log':
        f  = open(os.path.join(location, 'access_log'), "r")
        x = f.read()
        a1 = x.split('\n')
        a2 = a1.pop()
    #print(a1)
    for i in range(len(a1)):
        #print(a1[i])
        f1= re.match(regex3, a1[i]).groups()
        #print (re.match(regex3, a1[i]).groups())
        l.append(f1)
        i =i+1
    for k in l:
        reader = geoip2.database.Reader('GeoLite2-City.mmdb')
        data[i2] ={'IP':k[0],'Date':k[1],'Web':k[3],'Status':k[3],'Size':k[4],'country':listcountry[i2],'lat':listlat[i2],'lon':listlon[i2]}
        IP.append(k[0])
        Date.append(k[1])
        web.append(k[3])
        Stat.append(k[3])
        Country.append(listcountry[i2])
        Lat.append(listlat[i2])
        Lon.append(listlon[i2])
        i2 = i2 +1
#print(len(data))    
with open('data.json', 'w') as f:
    for jk in range(len(data)):
        json.dump(data[jk],  f, ensure_ascii=False)
        f.write('\n')
        
        
IPAA=[]
IPBB=[]
time=[]
cha="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"
for i in range(len(IP)):
    F= IP[i]
    if F[0] and F[-1] not in cha:
        IPAA.append(F)
IPAA.sort()
while len(IPAA) !=0:
    D=IPAA[0]
    R=IPAA.count(D)
#if IPAA[-1] ==IPAA[1]:
    for i in range(R):
        IPAA.remove(D)
    time.append(R)
    IPBB.append(D)

import geoip2.webservice
import geoip2.database
listcountry1 = []
listlat1 = []
listlon1 = []
reader = geoip2.database.Reader('GeoLite2-City.mmdb')
for ip1 in IPBB:
    if ip1 == "10.0.0.153":
        ip1 ='110.77.238.234'
    response = reader.city(ip1)
    x1 = response.country.name
    x2 = response.location.latitude
    x3 = response.location.longitude
    listcountry1.append(x1)
    listlat1.append(x2)
    listlon1.append(x3)
Date2=[]
for i in range(len(Date)):
    H = Date[i]
    #Date2.append(H[:pos])
    Find=H[3:6]
    if Find=="Mar":
        H=H.replace("Mar","03")
        pos= H.find(":")
        Date2.append(H[:pos])

# %%
import time
from datetime import date
import geoip2.webservice
import geoip2.database
reader = geoip2.database.Reader('GeoLite2-City.mmdb')
gew=data
cha="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"
new={}
p=0
eng=[]
book4=[]
count2=[]
IU=0
data2=[]
data3=[]
newdata={}
IPlist=[]
Statuslist=[]
Countrylist=[]
Countlist=[]
Datelist=[]
Latlist=[]
Lonlist=[]
newdata22={}
while p<len(data):
    dic1=gew[p]
    dicip=dic1["IP"]
    dicST=dic1["Status"]
    if dicip[0] and dicip[-1] not in cha:
        new[p]={"IP":IP[p],"Status":Stat[p],"Country":Country[p],"Date":Date2[p]}
        p+=1
    else:
        new[p]={"IP":IP[p],"Status":Stat[p],"Country":Country[p],"Date":Date2[p]}
        eng.append(p)
        p+=1
eng.reverse()
for i in range(len(new)):
    if i==eng[-1]:
        eng.pop()
    else:
        dic11=new[i]
        dicstat11=dic11["Status"]
        dicip=dic11["IP"]
        dicCou=dic11["Country"]
        data2.append(dic11)
sortdata=sorted(data2, key = lambda i: (i['IP'], i['Status'],i["Country"],i["Date"]))
while IU < len(sortdata):
    tor2=sortdata[IU]
    book4.append(tor2)
    S=sortdata.count(tor2)
    count2.append(S)
    IU+=S
for i in range(len(book4)):
    fil=book4[i]
    ty=count2[i]
    if fil["IP"] == "10.0.0.153":
        fil["IP"] = '110.77.238.234'
    response = reader.city(fil["IP"])
    x1 = response.country.name
    x2 = response.location.latitude
    x3 = response.location.longitude
    newdata[i]={"IP":fil["IP"],"Status":fil["Status"],"Country":fil["Country"],"Count":ty,"Date":fil["Date"],"Lat":x2,"Lon":x3}
    IPlist.append(fil["IP"])
    Statuslist.append(fil["Status"])
    Countrylist.append(fil["Country"])
    Countlist.append(ty)
    Datelist.append(fil["Date"])
for i in range(len(newdata)):
        dic22=newdata[i]
        data3.append(dic22)
sortdata2=sorted(data3, key = lambda i: (i['Count'])) 
sortdata2.reverse()
with open('newdata2.json', 'w') as f:
    for jk in range(len(sortdata2)):
        json.dump(sortdata2[jk],  f, ensure_ascii=False)
        f.write('\n')
s=0
for i in range(len(count2)):
    s+=int(count2[i])
Base=[]
for i in range(len(sortdata)):
    fil=sortdata[i]
    if fil["IP"] == "10.0.0.153":
        fil["IP"] = '110.77.238.234'
    response = reader.city(fil["IP"])
    x1 = response.country.name
    x2 = response.location.latitude
    x3 = response.location.longitude
    newdata22[i]={"IP":fil["IP"],"Status":fil["Status"],"Country":fil["Country"],"Date":fil["Date"],"Lat":x2,"Lon":x3}
    Base.append(newdata22[i])
with open('newdataGG.json', 'w') as f:
    for jk in range(len(Base)):
        json.dump(Base[jk],  f, ensure_ascii=False)
        f.write('\n')

# %%
def Seach_time():
    Line=1
    sortlist=[]
    curdata=sortdata2
    D1=int(Day_from.get())  
    D2=int(Day_to.get())
    M1=int(Month_from.get())
    M2=int(Month_to.get())
    Y1=int(Year_from.get())
    Y2=int(Year_to.get())
    for i in range(len(curdata)):
        S=curdata[i]
        sortlist.append(S)
    curdata=sorted(sortlist, key = lambda i: (i['Date']))
    mylist.delete(0,END)
    for i in range(len(curdata)):
        Row=curdata[i]
        seach_time=Row["Date"]
        year1=int(seach_time[6:10])
        month1=int(seach_time[3:5])
        day1=int(seach_time[:2])
        if Y2 >= year1 and year1 >= Y1:
            if M2 >= month1 and month1>= M1:
                if D2 >= day1 and day1>= D1:
                    mylist.insert(END,str(Line)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                        +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
                    Line+=1
        else:
            mylist.delete(0,END)

# %%
def OK_command():
    D1=int(Day_from.get())  
    D2=int(Day_to.get())
    M1=int(Month_from.get())
    M2=int(Month_to.get())
    Y1=int(Year_from.get())
    Y2=int(Year_to.get())
    All.clear()
    Good.clear()
    Food.clear()
    HTML_IP.clear()
    HTML_Date.clear()
    mylist.delete(0,END)
    for line in range(int(Data_text.get())):
        Row=curdata[line]
        Good[line]={"IP":Row["IP"],"Status":Row["Status"],"Date":Row["Date"]}
        Food[line]={"Country":Row["Country"],"Lat":Row["Lat"],"Lon":Row["Lon"]}
        All.append(Row)
        HTML_IP.append(Good[line])
        HTML_Date.append(Food[line])
        mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                  +"                                                                              "+Row["Status"]
                +"                                                                              "+Row["Country"]
                +"                                                                             "+str(Row["Count"])
                +"                                   "+Row["Date"])

# %%
def View_all_command():
    Good.clear()
    Food.clear()
    HTML_IP.clear()
    HTML_Date.clear()
    mylist.delete(0,END)
    for line in range(len(curdata)):
        Row=curdata[line]
        Good[line]={"IP":Row["IP"],"Status":Row["Status"],"Date":Row["Date"]}
        Food[line]={"Country":Row["Country"],"Lat":Row["Lat"],"Lon":Row["Lon"]}
        HTML_IP.append(Good[line])
        HTML_Date.append(Food[line])
        mylist.insert(END,str(line+1)
                      +"                                   "+Row["IP"]
                  +"                                                                              "+Row["Status"]
                +"                                                                              "+Row["Country"]
                +"                                                                             "+str(Row["Count"])
                +"                                   "+Row["Date"])
    curline=line+1
    #return Good
    #return Food

# %%
def get_Month(month):
    if month ==1:
        Mon ="01"
    elif month ==2:
        Mon ="02"
    elif month ==3:
        Mon ="03"
    elif month ==4:
        Mon ="04"
    elif month ==5:
        Mon ="05"
    elif month ==6:
        Mon ="06"
    elif month ==7:
        Mon ="07"
    elif month ==8:
        Mon ="08"
    elif month ==9:
        Mon ="09"
    elif month ==10:
        Mon ="10"
    elif month ==11:
        Mon ="11"
    elif month ==12:
        Mon ="12"
    return Mon

# %%
def IP_sort():
    sortlist=[]
    curdata=sortdata2
    if Data_text.get() != "":
        for i in range(int(Data_text.get())):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['IP']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
    else:
        for i in range(len(curdata)):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['IP']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])

def Status_sort():
    sortlist=[]
    curdata=sortdata2
    if Data_text.get() != "":
        for i in range(int(Data_text.get())):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Status']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
    else:
        for i in range(len(curdata)):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Status']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])

def Country_sort():
    sortlist=[]
    curdata=sortdata2
    if Data_text.get() != "":
        for i in range(int(Data_text.get())):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Country']))
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
    else:
        for i in range(len(curdata)):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Country']))
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
def Count_sort():
    sortlist=[]
    curdata=sortdata2
    if Data_text.get() != "":
        for i in range(int(Data_text.get())):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Count']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
    else:
        for i in range(len(curdata)):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Count']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])

def Date_sort():
    sortlist=[]
    curdata=sortdata2
    if Data_text.get() != "":
        for i in range(int(Data_text.get())):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Date']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])
    else:
        for i in range(len(curdata)):
            S=sortdata2[i]
            sortlist.append(S)
        curdata=sorted(sortlist, key = lambda i: (i['Date']))
        curdata.reverse()
        mylist.delete(0,END)
        for line in range(len(curdata)):
            Row=curdata[line]
            mylist.insert(END,str(line+1)+"                                   "+Row["IP"]
                      +"                                                                              "+Row["Status"]
                    +"                                                                              "+Row["Country"]
                    +"                                                                             "+str(Row["Count"])
                    +"                                   "+Row["Date"])

# %%
def Add_command():
    IP_text.get(),Status_text.get()
    import time
    from datetime import date
    import geoip2.webservice
    import geoip2.database
    reader = geoip2.database.Reader('GeoLite2-City.mmdb')
    response = reader.city(IP_text.get())
    CC=response.country.name
    NN=response.location.longitude
    AA=response.location.latitude
    curdata=sortdata2
    Some={}
    today = date.today()
    Month=get_Month(today.month)
    ADD=len(Good)
    Some.clear()
    if Data_text.get() != "":
        mylist.insert(END,str(int(Data_text.get())+1)+"                                   "+IP_text.get()+
                      "                                                                              "+Status_text.get()+
                    "                                                                              "+CC
                      +"                                   "+str(today.day)+"/"+Month+"/"+str(today.year))
    else:
        mylist.insert(END,str(len(All)+1)+"                                   "+IP_text.get()+
                      "                                                                              "+Status_text.get()+
                    "                                                                              "+CC
                      +"                                                                                                                "+str(today.day)+"/"+Month+"/"+str(today.year))
    Good[ADD]={"IP":IP_text.get(),"Status":Status_text.get(),"Date":str(today.day)+"/"+Month+"/"+str(today.year)}
    Food[ADD]={"Country":CC,"Lat":AA,"Lon":NN}
    Some={"IP":IP_text.get(),"Status":Status_text.get(),"Country":CC,"Date":"08"+"/"+Month+"/"+str(today.year),"Lat":AA,"Lon":NN}
    HTML_IP.append(Good[ADD])
    HTML_Date.append(Food[ADD])
    All.append(Some)

# %%
def create_Json():
    data_loG=[]
    with open('Log_File.json', 'w') as f:
        for jk in range(len(HTML_IP)):
            json.dump(HTML_IP[jk],f, ensure_ascii=False)
            f.write('\n')
    with open('Location_File.json', 'w') as f:
        for jk in range(len(HTML_Date)):
            json.dump(HTML_Date[jk],f, ensure_ascii=False)
            f.write('\n')
    with open('newdataGG.json',"a")as f:
        for jk in range(len(All)):
            json.dump(All[jk],f, ensure_ascii=False)
            f.write('\n')
    with open('C:/python3.7/Work_Sof2/Django/MyProject/blog/templates/blog/newdataGG.json',mode = 'r') as f:
        for line in f:
            r= ast.literal_eval(line)
            data_loG.append(r)
    print(len(data_loG))
    print(data_loG[-1])

# %%
def ShowW():
    D1=int(Day_from.get())  
    D2=int(Day_to.get())
    M1=int(Month_from.get())
    M2=int(Month_to.get())
    Y1=int(Year_from.get())
    Y2=int(Year_to.get())
    data_log=[]
    Fori=[]
    book45=[]
    count45=[]
    IU=0
    WO={}
    WOlist=[]
    Some={}
    with open('C:/python3.7/Work_Sof2/Django/MyProject/blog/templates/blog/newdataGG.json',mode = 'r') as f:
        for line in f:
            r= ast.literal_eval(line)
            data_log.append(r)
    for i in range(len(data_log)):
        WE=data_log[i]
        #Fori.append(WE["Date"])
        Seltime=WE["Date"]
        Year=int(Seltime[6:10])
        Month=int(Seltime[3:5])
        Day=int(Seltime[:2])
        if Y2>= Year >=Y1:
            #print(Month)
            #print("1")
            if M2>=3>=M1:
                #print("1")
                if D2>=Day>=D1:
                    Fori.append(WE)
    sortdataF=sorted(Fori, key = lambda i: (i['IP'], i['Status'],i["Country"],i["Date"]))
    Good.clear()
    Food.clear()
    HTML_IP.clear()
    All.clear()
    HTML_Date.clear()
    mylist.delete(0,END)
    for line in range(len(sortdataF)):
        Row=sortdataF[line]
        Some[line]={"IP":Row["IP"],"Status":Row["Status"],"Country":Row["Country"],"Date":Row["Date"],"Lat":Row["Lat"],"Lon":Row["Lon"]}
        Good[line]={"IP":Row["IP"],"Status":Row["Status"],"Date":Row["Date"]}
        Food[line]={"Country":Row["Country"],"Lat":Row["Lat"],"Lon":Row["Lon"]}
        All.append(Some)
        HTML_IP.append(Good[line])
        HTML_Date.append(Food[line])
        mylist.insert(END,str(line+1)
                      +"                                   "+Row["IP"]
                  +"                                                                              "+Row["Status"]
                +"                                                                              "+Row["Country"]
                +"                                   "+Row["Date"])

# %%
import sqlite3
import tkinter as tk
from tkinter import *
grod = "LightSteelBlue3"
HTML_IP=[]
HTML_Date=[]
Good={}
Food={}
All=[]
curdata=sortdata2
cu={}
display = tk.Tk()
v = tk.IntVar()
v.set(1)  # initializing the choice, i.e. Python
amount_data=[5,10,50,100]
Seach_data=["All","IP"]
languages = ["5","10","50","100"]
Label1=tk.Label(display, text="Choose amount of data",height=2,bg=grod).grid(row=0, column=0,columnspan=2,sticky=S)
Data_text=StringVar()
tk.Entry(display,textvariable=Data_text,width=21,bd=3).grid(row=1,column=0,columnspan=2,sticky=N)

Label2=tk.Label(display, text=" ",width=25,bg=grod).grid(row=0, column=2,columnspan=2)


Label4=tk.Label(display, text=" ",width=25,bg=grod).grid(row=0, column=6,columnspan=2)

Label5=tk.Label(display, text="Select range time",width=15,bg=grod).grid(row=0, column=8,columnspan=6)

Day_from = StringVar()
Day_to = StringVar()
Labelday_from=tk.Label(display, text="Day",bg=grod).grid(row=1, column=8,sticky=E)
Labelday_to=tk.Label(display, text="Day",bg=grod).grid(row=2, column=8,sticky=E)

Month_from = StringVar()
Month_to = StringVar()
Labelmonth_from=tk.Label(display, text="Month",bg=grod).grid(row=1, column=10)
Labelmonth_to=tk.Label(display, text="Month",bg=grod).grid(row=2, column=10)

Year_from = StringVar()
Year_to = StringVar()
Labelyear_from=tk.Label(display, text="Year",bg=grod).grid(row=1, column=12)
Labelyear_to=tk.Label(display, text="Year",bg=grod).grid(row=2, column=12)

day_from = Spinbox(display, from_=1, to=31,width=2,bd=3,textvariable=Day_from).grid(row=1,column=9,sticky=W)
month_from =Spinbox(display, from_=1, to=12,width=2,bd=3,textvariable=Month_from).grid(row=1,column=11)
year_from =Spinbox(display, from_=1999, to=2019,width=4,bd=3,textvariable=Year_from).grid(row=1,column=13)

day_to = Spinbox(display, from_=1, to=31,width=2,bd=3,textvariable=Day_to).grid(row=2,column=9,sticky=W)
month_to =Spinbox(display, from_=1, to=12,width=2,bd=3,textvariable=Month_to).grid(row=2,column=11)
year_to =Spinbox(display, from_=1999, to=2019,width=4,bd=3,textvariable=Year_to).grid(row=2,column=13)

view_but=tk.Button(display,text="OK",height=3,width=20,command=ShowW,bg="LightSkyBlue1",bd=2).grid(row=1,column=3,columnspan=2)

seach_time=tk.Button(display,text="Seach",height=3,width=20,command=Seach_time,bg="LightSkyBlue1",bd=2).grid(row=1,column=6,columnspan=2)

viewall_but=tk.Button(display,text="View all",height=3,width=20,command=View_all_command,bg="LightSkyBlue1",bd=2).grid(row=7,column=5,columnspan=2,sticky=E)

viewall_but=tk.Button(display,text="Create Json",height=3,width=20,bg="LightSkyBlue1",bd=2,command=create_Json).grid(row=7,column=12,columnspan=2,sticky=E)

tk.Button(display, text="IP",bg="LightSkyBlue1",width=45,command=IP_sort).grid(row=4, column=0,columnspan=3)

tk.Button(display, text="Status",bg="LightSkyBlue1",width=25,command=Status_sort).grid(row=4, column=3,columnspan=2)

tk.Button(display, text="Country",bg="LightSkyBlue1",width=50,command=Country_sort).grid(row=4, column=5,columnspan=3)

tk.Button(display, text="Count",bg="LightSkyBlue1",width=20,command=Count_sort).grid(row=4, column=8,columnspan=2)

tk.Button(display, text="Date",bg="LightSkyBlue1",width=30,command=Date_sort).grid(row=4, column=10,columnspan=4)

scrollbar = Scrollbar(display,width=20,bd=30)
scrollbar.grid(row = 5,column=14,rowspan=2,sticky=N)


mylist = Listbox(display, yscrollcommand = scrollbar.set ,width=205,height=20,bg="snow2")

mylist.grid(row=5,column=0,columnspan=14)
scrollbar.config( command = mylist.yview )

tk.Label(display, text="IP",height=2,width=10,bg=grod).grid(row=6, column=0,sticky=E)
IP_text=StringVar()
tk.Entry(display,textvariable=IP_text,bd=3).grid(row=6,column=1,columnspan=3,sticky=W)

tk.Label(display, text="Status",height=2,width=10,bg=grod).grid(row=7, column=0,sticky=E)
Status_text=StringVar()
tk.Entry(display,textvariable=Status_text,bd=3).grid(row=7,column=1,columnspan=3,sticky=W)


tk.Button(display,text="Add",height=2,width=10,bg="LightSkyBlue1",command=Add_command,bd=2).grid(row=6,column=2,columnspan=2,rowspan=3,sticky=E)

display.configure(background=grod)

display.mainloop()
# Out:
# 840
# {'IP': '219.75.27.16', 'Status': '200', 'Country': 'Singapore', 'Date': '08/03/2019', 'Lat': 103.8558, 'Lon': 1.2931}
